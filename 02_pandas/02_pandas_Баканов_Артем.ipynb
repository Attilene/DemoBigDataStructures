# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# ## Лабораторная работа №2

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
path = "D:/FinUniver/Технологии обработки больших данных/Семинары/02_pandas/data/"

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца(ов) с индексами.

# %%
recipes = pd.read_csv(path + "recipes_sample.csv", sep=',')
reviews = pd.read_csv(path + "reviews_sample.csv", sep=',')
reviews.rename(columns = {"Unnamed: 0": "index"}, inplace=True)
reviews = reviews.set_index("index")

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print("Таблица recipes:")
print(len(recipes))
print(len(recipes.columns))
print(recipes.dtypes, '\n')

print("Таблица reviews:")
print(len(reviews))
print(len(reviews.columns))
print(reviews.dtypes)
# Out:
# Таблица recipes:
# 30000
# 8
# name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
#
# Таблица reviews:
# 126696
# 6
# Unnamed: 0     int64
# user_id        int64
# recipe_id      int64
# date          object
# rating         int64
# review        object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print("Таблица recipes:")
print(recipes.isnull().sum())
print("Доля пропусков:", sum([True for idx, row in recipes.iterrows() if any(row.isnull())]) / len(recipes), '\n')

print("Таблица reviews:")
print(reviews.isnull().sum())
print("Доля пропусков:", sum([True for idx, row in reviews.iterrows() if any(row.isnull())]) / len(reviews))
# Out:
# Таблица recipes:
# name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64
# Доля пропусков: 0.5684666666666667
#
# Таблица reviews:
# user_id       0
# recipe_id     0
# date          0
# rating        0
# review       17
# dtype: int64
# Доля пропусков: 0.00013417945317926376

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print("Таблица recipes:")
print(recipes[["id", "minutes", "contributor_id", "n_steps", "n_ingredients"]].mean(), "\n")

print("Таблица reviews:")
print(reviews[["user_id", "recipe_id", "rating"]].mean())
# Out:
# Таблица recipes:
# id                2.218793e+05
# minutes           1.233581e+02
# contributor_id    5.635901e+06
# n_steps           9.805582e+00
# n_ingredients     9.008286e+00
# dtype: float64
#
# Таблица reviews:
# user_id      1.408013e+08
# recipe_id    1.600944e+05
# rating       4.410802e+00
# dtype: float64

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
rand_recipes = recipes.sample(n=10)
rand_recipes
# Out:
#                                     name      id  minutes  contributor_id  \
# 28621                  vegan sloppy joes  105705       35           37584
# 15812                lemon basil chicken  190828       30          289680
# 8242   creamy crock pot chicken  low fat  244254      365          548030
# 11574                        frozen rose  279526        5          431813
# 25399       spicy grilled turkey burgers  182596       20           86764
# 6197            chile scalloped potatoes   91887      110           60540
# 1291              asparagus garden salsa  176085       70          133174
# 5330           cheesy tater tots chicken  143616       90          199525
# 11889             georgia s city chicken  471703      330           63553
# 21347       posh yellow squash casserole   65456       50           90341
#
#         submitted  n_steps                                        description  \
# 28621  2004-12-08     16.0  this is a simple and delicious sandwich. it is...
# 15812  2006-10-15      NaN  i made this to go with my squash and parmesan ...
# 8242   2007-08-03      NaN  i'm not sure where i got this one, but i've ma...
# 11574  2008-01-17      2.0    blended strawberry cocktail using tequila rose.
# 25399  2006-08-24      NaN  i'd never tried ground turkey meat before.  i ...
# 6197   2004-05-26      5.0                            more tempting chiles...
# 1291   2006-07-04      3.0  this recipe caught my attention as it was quit...
# 5330   2005-11-02      3.0  a satisfying side dish or a hearty main meal w...
# 11889  2012-01-10      NaN  there is no chicken in city chicken!  \r\n\r\n...
# 21347  2003-06-24      7.0  this is such an easy recipe to make and everyo...
#
#        n_ingredients
# 28621            9.0
# 15812            NaN
# 8242             5.0
# 11574            NaN
# 25399            8.0
# 6197             8.0
# 1291             8.0
# 5330             5.0
# 11889            NaN
# 21347            8.0

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.index = np.arange(len(reviews))
reviews.head()
# Out:
#       user_id  recipe_id        date  rating  \
# 0       21752      57993  2003-05-01       5
# 1      431813     142201  2007-09-16       5
# 2      400708     252013  2008-01-10       4
# 3  2001852463     404716  2017-12-11       5
# 4       95810     129396  2008-03-14       5
#
#                                               review
# 0  Last week whole sides of frozen salmon fillet ...
# 1  So simple and so tasty!  I used a yellow capsi...
# 2  Very nice breakfast HH, easy to make and yummy...
# 3  These are a favorite for the holidays and so e...
# 4  Excellent soup!  The tomato flavor is just gre...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes[(recipes["minutes"] <= 20) & (recipes["n_ingredients"] <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# 112                                   10 minute lime pie  513963       10
# 117                               100 year old pie crust  126072       15
# 121                            1000 island vegetable dip  121712       20
# 143                                    2 minute broccoli  256464        4
# 165                                        3 fruit salad  112648       15
# 168                        3 ingredient moroccan dry rub  505748        3
# 182                               3 minute apple cobbler  137187        2
# 214                                       5 minute chili  116672        5
# 225                                          5 spice tea  407747       20
# 254                            a different spinach salad  317681        5
# 257                    a different tomato salad dressing  223242        5
# 267                              a potato salad sandwich  504948        5
# 271                                    a simple macaroon  149966       20
# 284                                   a 1 romanian steak  115776       20
# 286                      a  m  couscous  ww 5 pointsplus  446600       10
# 303                       abuelito wato s grilled cheese  366021       12
# 333                               adam s fruit popsicles  229252       10
# 346                              adult cherry cola drink  206136        2
# 349                       adult s cherry vanilla limeade  351371        2
# 367                                      african lullaby  292695        5
# 383                                       afterburner  3  240135        2
# 389                                         agua de meln  301164       15
# 390                                agua fresca de pepino  301365       15
# 423                             alcoholic shirley temple  276396        2
# 427                                   alex s lemon shake  303710        5
# ...                                                  ...     ...      ...
# 29555  ww 1 point   arepas  alternative to tortillas ...  121786       18
# 29564                   ww 3 points bean   cheese nachos  207243       10
# 29609                                 ww roasted carrots  187151        5
# 29625                                   x rated flirtini  259045        2
# 29653                                       yellow birds   12791        3
# 29688                yogurt cumin fish fillets  flounder  250078       15
# 29694                                   yogurt popsicles  236534       10
# 29695                        yogurt  granola and bananas  103435        5
# 29720                                 yule mule cocktail  443502        4
# 29721                                     yuletide shrub   71400        5
# 29723                              yum yum avocado salsa  296231       10
# 29732                               yummy bagel sandwich  255378        5
# 29751                         yummy garlicky green beans  437046       20
# 29754                    yummy honey and pear sandwiches  171091        2
# 29770  yummy mummy cheese spread  mummy shape  halloween  333510       10
# 29789                         yummy sour cream fruit dip  200350        5
# 29792                                    yummy sweet tea  400519        7
# 29798                        yummy  scrummy banana shake  173389        5
# 29817                                  zen wine spritzer  498523        1
# 29820                                  zesty baked beans  225065       12
# 29836                              zesty grilled veggies  168735       20
# 29851            zesty raspberry chipotle black bean dip  507063       17
# 29855       zesty skillet chicken you can t live without  402257       20
# 29858                               zesty stuffed olives  269904       10
# 29866                          zhanyshpa from kazakhstan  160599       15
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# 28             213909  2008-05-06     11.0
# 60             213909  2008-05-16      NaN
# 90              58104  2004-09-29      4.0
# 91              47892  2008-02-13      NaN
# 94               4470  2001-09-03      NaN
# 112           2284242  2014-03-04     12.0
# 117            205983  2005-06-15      NaN
# 121            210965  2005-05-12      3.0
# 143            165433  2007-10-01      7.0
# 165            107135  2005-03-04      NaN
# 168             65502  2013-08-12      NaN
# 182             17803  2005-09-12      3.0
# 214              4439  2005-04-12      2.0
# 225            107583  2010-01-11      7.0
# 254            808027  2008-08-05      NaN
# 257            461283  2007-04-17      3.0
# 267           2549237  2013-07-29      NaN
# 271            262129  2006-01-01      5.0
# 284            177443  2005-04-07      7.0
# 286            599450  2011-01-16      5.0
# 303            323731  2009-04-15      3.0
# 333             57042  2007-05-22      4.0
# 346            185387  2007-01-18      2.0
# 349            422893  2009-01-22      NaN
# 367            327115  2008-03-19      NaN
# 383            383346  2007-07-12      3.0
# 389            327115  2008-04-29      5.0
# 390            327115  2008-04-29      NaN
# 423            649758  2008-01-03      1.0
# 427             85157  2008-05-15      NaN
# ...               ...         ...      ...
# 29555          120566  2005-05-12     16.0
# 29564          111342  2007-01-23      5.0
# 29609          290998  2006-09-20      5.0
# 29625          372895  2007-10-15      1.0
# 29653            8575  2001-10-16      NaN
# 29688          207176  2007-08-31      6.0
# 29694           57042  2007-06-22      5.0
# 29695           58104  2004-11-05      NaN
# 29720          135470  2010-12-03      NaN
# 29721           94612  2003-09-14      NaN
# 29723          808017  2008-04-03      5.0
# 29732          430471  2007-09-25      2.0
# 29751          622491  2010-09-10      NaN
# 29754          318506  2006-06-02      3.0
# 29770          488441  2008-10-28      NaN
# 29789           57562  2006-12-12      3.0
# 29792          281166  2009-11-20      NaN
# 29798          322326  2006-06-17      NaN
# 29817         2585084  2013-04-06      3.0
# 29820          350234  2007-04-27      4.0
# 29836            9717  2006-05-19      NaN
# 29851         2143923  2013-09-18      5.0
# 29855          369264  2009-12-02      3.0
# 29858          226066  2007-12-05      NaN
# 29866          279179  2006-03-20      NaN
# 29873          724218  2008-05-27      9.0
# 29874           24386  2003-10-29      8.0
# 29905          305531  2007-09-29      4.0
# 29980          305531  2008-08-20      3.0
# 29983          152500  2006-03-31      6.0
#
#                                              description  n_ingredients
# 28     this is a wonderful quick bread to make as an ...            5.0
# 60     this recipe is so simple and the flavors are s...            5.0
# 90     pineapple mimosa was changed to hawaiian sunri...            3.0
# 91     "mmmm, i love bananas!" a --tasty dish-- origi...            4.0
# 94     this is a real short cut for cooks in a hurry....            2.0
# 112    a super easy stand-in for traditional key lime...            5.0
# 117                                very nice light crust            5.0
# 121    this is a delicious yet quick and easy vegetab...            2.0
# 143    so easy.  tender crisp.  hot, steamed broccoli...            2.0
# 165    we have this at the holidays, like everyone el...            5.0
# 168    who says that recipes have to be complicated t...            3.0
# 182                       food & family fall 2005 issue.            4.0
# 214    easy recipe, delicious topped with minced jala...            3.0
# 225    can be served hot or iced.  use sweetener of c...            4.0
# 254    this salad combines fresh spinach with strawbe...            5.0
# 257    for an easy, tasty, and different twist on the...            3.0
# 267    this sandwich is based wholly on potato salad....            5.0
# 271    this cookie is made without flour and without ...            5.0
# 284    from "famous steakhouse recipes" by a-1 steak ...            5.0
# 286    based on a recipe from the january/february 20...            4.0
# 303    when our family visited puerto rico the only t...            4.0
# 333    i have not tried this recipe. i got it from ev...            3.0
# 346    i got this recipe off the net and it's a nice ...            3.0
# 349                    another one from cowboy cocktails            5.0
# 367               this is a great, creamy amarula drink.            5.0
# 383    a drink not too sweet.  in this drink, we can ...            4.0
# 389    a very refreshing summer drink. i like it beca...            4.0
# 390              a very refreshing drink for the summer.            4.0
# 423    go back in time to your childhood but with an ...            4.0
# 427    here is the story of this recipe in alex's own...            5.0
# ...                                                  ...            ...
# 29555  from ww magazine. eat these plain or add a spr...            4.0
# 29564                                      from ww site.            4.0
# 29609  this is the only way i will eat carrots. they ...            5.0
# 29625                        from www.drinkpinkvodka.com            5.0
# 29653                                                NaN            5.0
# 29688  can use any fish you like.  from a community c...            4.0
# 29694  i have not tried this recipe. i got it from a ...            4.0
# 29695  i have this guilt free dish to start the day a...            5.0
# 29720       like a tom collins, only better. ho, ho, ho!            4.0
# 29721   great christmas punch, that is not overly sweet.            5.0
# 29723                        this is yummy! and healthy!            4.0
# 29732  i serve this open faced, but you could make it...            4.0
# 29751  attempted to make green beans like the chinese...            4.0
# 29754  i went looking for sandwich fillings for my on...            4.0
# 29770  originally from taste of home by revecca eremi...            5.0
# 29789  mock jason's deli fruit dip. i've made it and ...            3.0
# 29792  i bet you can't have just one sip of this deli...            3.0
# 29798  there are no other words for it, it is yummy, ...            5.0
# 29817  this is a light and refreshing beverage that i...            4.0
# 29820           this came from a healthy recipe website.            5.0
# 29836                                        from kraft.            5.0
# 29851  this creamy, tangy, mildly spicy dip is always...            5.0
# 29855  another betty crocker recipe.  i love the simp...            4.0
# 29858                 from kraft.  too cute not to try!!            4.0
# 29866            this is another typical kazakh dessert.            4.0
# 29873  i haven't tried this yet, but i am going to so...            5.0
# 29874  a fun thing for kids to do. may want to use mi...            3.0
# 29905  from betty crocker fresh spring recipes. i lik...            5.0
# 29980                                  simple and yummy!            3.0
# 29983  this dish is from tim malzer, a german chef wh...            5.0
#
# [2019 rows x 8 columns]

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes["submitted"] = pd.to_datetime(recipes["submitted"])

recipes_2 = pd.read_csv(path + "recipes_sample.csv", sep=',', parse_dates = ["submitted"], date_parser = lambda x: datetime.strptime(x, '%Y-%m-%d'))
recipes_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
# name              30000 non-null object
# id                30000 non-null int64
# minutes           30000 non-null int64
# contributor_id    30000 non-null int64
# submitted         30000 non-null datetime64[ns]
# n_steps           18810 non-null float64
# description       29377 non-null object
# n_ingredients     21120 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[recipes["submitted"] < "2011-01-01"]
# Out:
#                                                     name      id  minutes  \
# 0                  george s at the cove  black bean soup   44123       90
# 1                     healthy for them  yogurt popsicles   67664       10
# 2                           i can t believe it s spinach   38798       30
# 3                                   italian  gut busters   35173       45
# 4               love is in the air  beef fondue   sauces   84797       25
# 5                               mennonite  corn fritters   44045       15
# 6                                   open sesame  noodles  107229       28
# 7                             say what   banana sandwich   95926        5
# 9                                 412 broccoli casserole  306168       40
# 10                                      25 000 casserole   50662      125
# 11                         250 00 chocolate chip cookies  118843       20
# 12                                     ara s potato  oup   69190      135
# 14                              add in anything  muffins  149593       15
# 15                          better than tofu  cheesecake  200148       90
# 16                     burek  or feta cheese  phyllo pie  310570       65
# 17                   da best  chicago style italian beef   95534      645
# 18                             german  barbecued carrots  109818       55
# 19                                   healthy  fried rice   66932       25
# 20                    i can t believe i made cream puffs  226001       55
# 21                      kelly s creamy cheddar pea salad  125195       20
# 22                         kicked up  oven fried chicken  141939      345
# 23            margarita  dip for fresh  or grilled fruit  250883       70
# 24                 middle eastern   twice baked potatoes  120297      110
# 25                        pass me another   hot clam dip  147477       15
# 26                         pasta  with shrimp   eggplant  223349       50
# 27                               pizza pan  potato skins   60938       60
# 28                                   quick biscuit bread  302399       20
# 29                       secret ingredient  bbq meatloaf  342620       75
# 30      skordy  new potatoes w rosemary lemon   olive oi  296983       35
# 31                          sticky chicky   dump chicken  166089       55
# ...                                                  ...     ...      ...
# 29967                                zucchini spice cake   80067       65
# 29968                             zucchini spice muffins  324642       35
# 29969                                    zucchini strips  279769       30
# 29970               zucchini stuffed with feta and basil   72857       30
# 29971         zucchini stuffed with goat cheese and mint  130447       30
# 29972        zucchini tart with gruyere cheese and herbs  378799       35
# 29973                          zucchini tarte with bacon  335783       80
# 29974                              zucchini tomato salsa  321224       20
# 29975                               zucchini tomato toss   41095       15
# 29977                        zucchini wheat germ cookies  174719       30
# 29978                 zucchini with bacon corn   peppers  326105       45
# 29979               zucchini with bell pepper and tomato  363362       13
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29981                                zucchini with pasta   96162       30
# 29982                          zucchini with pesto sauce   34481       41
# 29983                          zucchini with serrano ham  162411       15
# 29984  zucchini  corn  black bean  and jack cheese qu...   36349       30
# 29985  zucchini  pineapple  ginger jam kicked up with...  325574       50
# 29986                 zucchini  potato and herb fritters  344542       30
# 29987    zucchini carrot cake with cream cheese frosting  112591       80
# 29988                            zucchini carrot muffins  287490       40
# 29989                         zucchini cheddar casserole   74023       50
# 29990                       zucchini pineapple loaf cake   71450       70
# 29991                           zucchini potato pancakes  180833       45
# 29992  zucchini  courgette soup  good for weight watc...  415406       45
# 29993                          zuni caf zucchini pickles  316950     2895
# 29995       zurie s holey rustic olive and cheddar bread  267661       80
# 29996               zwetschgenkuchen  bavarian plum cake  386977      240
# 29997        zwiebelkuchen   southwest german onion cake  103312       75
# 29999             cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# 5               41706 2002-10-25      NaN
# 6              173674 2004-12-30      8.0
# 7              118163 2004-07-20      4.0
# 9               50969 2008-05-30      6.0
# 10               9748 2003-01-10      NaN
# 11             145599 2005-04-24      NaN
# 12              98404 2003-08-20      5.0
# 14              89831 2005-12-28      NaN
# 15             261027 2006-12-11     18.0
# 16             676820 2008-06-24     38.0
# 17              94272 2004-07-13      NaN
# 18              64918 2005-01-28      NaN
# 19              93406 2003-07-16      NaN
# 20             237783 2007-05-02      NaN
# 21             113941 2005-06-09      5.0
# 22              89831 2005-10-19     13.0
# 23             398160 2007-09-04     14.0
# 24             197023 2005-05-02     14.0
# 25             135442 2005-12-05      3.0
# 26             452592 2007-04-18      7.0
# 27              35635 2003-04-24      NaN
# 28             213909 2008-05-06     11.0
# 29              50969 2008-12-09      9.0
# 30             718054 2008-04-08      NaN
# 31             290107 2006-04-27     14.0
# ...               ...        ...      ...
# 29967            4439 2004-01-02     11.0
# 29968          613544 2008-09-11      NaN
# 29969          522304 2008-01-18      8.0
# 29970           95743 2003-10-08      NaN
# 29971          182809 2005-07-19     14.0
# 29972          177443 2009-06-24     16.0
# 29973          930100 2008-11-08     10.0
# 29974          464080 2008-08-25      4.0
# 29975           47579 2002-09-24      3.0
# 29977          135870 2006-06-26      7.0
# 29978          896136 2008-09-19      8.0
# 29979          344321 2009-03-29     19.0
# 29980          305531 2008-08-20      3.0
# 29981          125388 2004-07-22      NaN
# 29982            4470 2002-07-17      8.0
# 29983          152500 2006-03-31      6.0
# 29984            3288 2002-08-05      NaN
# 29985           58104 2008-09-18     15.0
# 29986          197023 2008-12-21      8.0
# 29987          176348 2005-03-03      NaN
# 29988          227586 2008-02-21      NaN
# 29989           89831 2003-10-24     14.0
# 29990           89831 2003-09-15      NaN
# 29991          186118 2006-08-07      NaN
# 29992          485109 2010-03-04      5.0
# 29993           62264 2008-07-31      NaN
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# 5      ok - my heritage has been revealed. :) these a...            NaN
# 6      this is a very versatile and widely enjoyed pa...           12.0
# 7                 you just have to try it to believe it.            NaN
# 9      since there are already 411 recipes for brocco...            NaN
# 10     this is a recipe that my mother got from some ...            NaN
# 11           these are great! the perfect name for them!           13.0
# 12     i made this recipe myself when i was 13. i was...            NaN
# 14     this is a never-fail muffin recipe, it's a bla...            9.0
# 15     this is, again, from vegweb.com. this got abso...           13.0
# 16     ok, there are different version of burek (some...            6.0
# 17     tender, garlicky and full of oregano 'n stuff!...            NaN
# 18     this is something my grandma made at christmas...            NaN
# 19     i made this once, hoping to have something lig...            8.0
# 20     my old friend pat gave me this recipe 20 years...            6.0
# 21     i'm not a big fan of peas, but like them in th...           10.0
# 22     i make mine on one cookie rack placed on a bak...           17.0
# 23     this cool and creamy dip is a refreshing treat...            4.0
# 24     a delicious yet low-fat twice-baked potato sid...           10.0
# 25     this recipe is from an appetizer book that i i...            7.0
# 26     a nice low carb way to feel like you are eatin...            9.0
# 27     there's a pub we go to that makes their own fr...            7.0
# 28     this is a wonderful quick bread to make as an ...            5.0
# 29     i know what you might be thinking,'ho hum, ano...           10.0
# 30     i took this recipe from a vegan tastes of gree...            6.0
# 31     i found this recipe online. the idea here is t...            5.0
# ...                                                  ...            ...
# 29967  this recipe is pretty close to bizzare, but it...            4.0
# 29968  from robin hood home baking cookbook. these fr...           11.0
# 29969              spicy, salty, crispy zucchini strips!            4.0
# 29970  easy to make, savory and a nice presentation. ...            5.0
# 29971  this was past on to me by a gentleman friend w...           10.0
# 29972  this tart is wonderful picnic, potluck or part...           11.0
# 29973  this is another recipe from mark bittman's coo...            NaN
# 29974  a contest winner from taste of home.  it state...           13.0
# 29975  i tried a similar recipe but altered most of i...           10.0
# 29977  since i have an abundance of zucchini in my ga...           14.0
# 29978  this is a very colorful addition to any meal. ...            7.0
# 29979  the weather has been turning warmer and i have...            8.0
# 29980                                  simple and yummy!            3.0
# 29981  you can never have too many zucchini recipes. ...            9.0
# 29982  if you are not fond of basil substitute with s...            NaN
# 29983  this dish is from tim malzer, a german chef wh...            5.0
# 29984  one of those email recipes i haven't tried yet...           11.0
# 29985  i came up with this sweet and spicy jam after ...            8.0
# 29986  adapted from a recipe in 'the australian women...           12.0
# 29987  this recipe is good to have around when zucchi...           15.0
# 29988  got this recipe from from family circle, march...           13.0
# 29989         this has been a long time family favorite!            8.0
# 29990  i got this recipe from a local paper a long ti...            NaN
# 29991  this recipe was posted in our local newspaper,...            9.0
# 29992  this is a favourite winter warmer. by british ...            NaN
# 29993  refrigerator pickles for some of the zucchini ...            8.0
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
# [27661 rows x 8 columns]

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes["description_length"] = recipes["description"].str.len()
recipes
# Out:
#                                                     name      id  minutes  \
# 0                  george s at the cove  black bean soup   44123       90
# 1                     healthy for them  yogurt popsicles   67664       10
# 2                           i can t believe it s spinach   38798       30
# 3                                   italian  gut busters   35173       45
# 4               love is in the air  beef fondue   sauces   84797       25
# 5                               mennonite  corn fritters   44045       15
# 6                                   open sesame  noodles  107229       28
# 7                             say what   banana sandwich   95926        5
# 8                     1 in canada chocolate chip cookies  453467       45
# 9                                 412 broccoli casserole  306168       40
# 10                                      25 000 casserole   50662      125
# 11                         250 00 chocolate chip cookies  118843       20
# 12                                     ara s potato  oup   69190      135
# 13               blepandekager   danish   apple pancakes  503475       50
# 14                              add in anything  muffins  149593       15
# 15                          better than tofu  cheesecake  200148       90
# 16                     burek  or feta cheese  phyllo pie  310570       65
# 17                   da best  chicago style italian beef   95534      645
# 18                             german  barbecued carrots  109818       55
# 19                                   healthy  fried rice   66932       25
# 20                    i can t believe i made cream puffs  226001       55
# 21                      kelly s creamy cheddar pea salad  125195       20
# 22                         kicked up  oven fried chicken  141939      345
# 23            margarita  dip for fresh  or grilled fruit  250883       70
# 24                 middle eastern   twice baked potatoes  120297      110
# 25                        pass me another   hot clam dip  147477       15
# 26                         pasta  with shrimp   eggplant  223349       50
# 27                               pizza pan  potato skins   60938       60
# 28                                   quick biscuit bread  302399       20
# 29                       secret ingredient  bbq meatloaf  342620       75
# ...                                                  ...     ...      ...
# 29970               zucchini stuffed with feta and basil   72857       30
# 29971         zucchini stuffed with goat cheese and mint  130447       30
# 29972        zucchini tart with gruyere cheese and herbs  378799       35
# 29973                          zucchini tarte with bacon  335783       80
# 29974                              zucchini tomato salsa  321224       20
# 29975                               zucchini tomato toss   41095       15
# 29976                                      zucchini tots  505053       20
# 29977                        zucchini wheat germ cookies  174719       30
# 29978                 zucchini with bacon corn   peppers  326105       45
# 29979               zucchini with bell pepper and tomato  363362       13
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29981                                zucchini with pasta   96162       30
# 29982                          zucchini with pesto sauce   34481       41
# 29983                          zucchini with serrano ham  162411       15
# 29984  zucchini  corn  black bean  and jack cheese qu...   36349       30
# 29985  zucchini  pineapple  ginger jam kicked up with...  325574       50
# 29986                 zucchini  potato and herb fritters  344542       30
# 29987    zucchini carrot cake with cream cheese frosting  112591       80
# 29988                            zucchini carrot muffins  287490       40
# 29989                         zucchini cheddar casserole   74023       50
# 29990                       zucchini pineapple loaf cake   71450       70
# 29991                           zucchini potato pancakes  180833       45
# 29992  zucchini  courgette soup  good for weight watc...  415406       45
# 29993                          zuni caf zucchini pickles  316950     2895
# 29994                                     zuppa by luisa  464576       70
# 29995       zurie s holey rustic olive and cheddar bread  267661       80
# 29996               zwetschgenkuchen  bavarian plum cake  386977      240
# 29997        zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                        zydeco soup  486161       60
# 29999             cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# 5               41706 2002-10-25      NaN
# 6              173674 2004-12-30      8.0
# 7              118163 2004-07-20      4.0
# 8             1848091 2011-04-11     12.0
# 9               50969 2008-05-30      6.0
# 10               9748 2003-01-10      NaN
# 11             145599 2005-04-24      NaN
# 12              98404 2003-08-20      5.0
# 13             128473 2013-07-08     10.0
# 14              89831 2005-12-28      NaN
# 15             261027 2006-12-11     18.0
# 16             676820 2008-06-24     38.0
# 17              94272 2004-07-13      NaN
# 18              64918 2005-01-28      NaN
# 19              93406 2003-07-16      NaN
# 20             237783 2007-05-02      NaN
# 21             113941 2005-06-09      5.0
# 22              89831 2005-10-19     13.0
# 23             398160 2007-09-04     14.0
# 24             197023 2005-05-02     14.0
# 25             135442 2005-12-05      3.0
# 26             452592 2007-04-18      7.0
# 27              35635 2003-04-24      NaN
# 28             213909 2008-05-06     11.0
# 29              50969 2008-12-09      9.0
# ...               ...        ...      ...
# 29970           95743 2003-10-08      NaN
# 29971          182809 2005-07-19     14.0
# 29972          177443 2009-06-24     16.0
# 29973          930100 2008-11-08     10.0
# 29974          464080 2008-08-25      4.0
# 29975           47579 2002-09-24      3.0
# 29976          798181 2013-07-31      NaN
# 29977          135870 2006-06-26      7.0
# 29978          896136 2008-09-19      8.0
# 29979          344321 2009-03-29     19.0
# 29980          305531 2008-08-20      3.0
# 29981          125388 2004-07-22      NaN
# 29982            4470 2002-07-17      8.0
# 29983          152500 2006-03-31      6.0
# 29984            3288 2002-08-05      NaN
# 29985           58104 2008-09-18     15.0
# 29986          197023 2008-12-21      8.0
# 29987          176348 2005-03-03      NaN
# 29988          227586 2008-02-21      NaN
# 29989           89831 2003-10-24     14.0
# 29990           89831 2003-09-15      NaN
# 29991          186118 2006-08-07      NaN
# 29992          485109 2010-03-04      5.0
# 29993           62264 2008-07-31      NaN
# 29994          226863 2011-09-20     14.0
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      An original recipe created by chef scott meska...           18.0
# 1      My children and their friends ask for my homem...            NaN
# 2                These were so go, it surprised even me.            8.0
# 3      My sister-in-law made these for us at a family...            NaN
# 4      I think a fondue is a very romantic casual din...            NaN
# 5      Ok - my heritage has been revealed. :) these a...            NaN
# 6      This is a very versatile and widely enjoyed pa...           12.0
# 7                 You just have to try it to believe it.            NaN
# 8      This is the recipe that we use at my school ca...           11.0
# 9      Since there are already 411 recipes for brocco...            NaN
# 10     This is a recipe that my mother got from some ...            NaN
# 11           These are great! the perfect name for them!           13.0
# 12     I made this recipe myself when i was 13. i was...            NaN
# 13     This recipe has been posted here for play in z...            NaN
# 14     This is a never-fail muffin recipe, it's a bla...            9.0
# 15     This is, again, from vegweb.com. this got abso...           13.0
# 16     Ok, there are different version of burek (some...            6.0
# 17     Tender, garlicky and full of oregano 'n stuff!...            NaN
# 18     This is something my grandma made at christmas...            NaN
# 19     I made this once, hoping to have something lig...            8.0
# 20     My old friend pat gave me this recipe 20 years...            6.0
# 21     I'm not a big fan of peas, but like them in th...           10.0
# 22     I make mine on one cookie rack placed on a bak...           17.0
# 23     This cool and creamy dip is a refreshing treat...            4.0
# 24     A delicious yet low-fat twice-baked potato sid...           10.0
# 25     This recipe is from an appetizer book that i i...            7.0
# 26     A nice low carb way to feel like you are eatin...            9.0
# 27     There's a pub we go to that makes their own fr...            7.0
# 28     This is a wonderful quick bread to make as an ...            5.0
# 29     I know what you might be thinking,'ho hum, ano...           10.0
# ...                                                  ...            ...
# 29970  Easy to make, savory and a nice presentation. ...            5.0
# 29971  This was past on to me by a gentleman friend w...           10.0
# 29972  This tart is wonderful picnic, potluck or part...           11.0
# 29973  This is another recipe from mark bittman's coo...            NaN
# 29974  A contest winner from taste of home.  it state...           13.0
# 29975  I tried a similar recipe but altered most of i...           10.0
# 29976  'the happy homemaker blog' shared this recipe ...            NaN
# 29977  Since i have an abundance of zucchini in my ga...           14.0
# 29978  This is a very colorful addition to any meal. ...            7.0
# 29979  The weather has been turning warmer and i have...            8.0
# 29980                                  Simple and yummy!            3.0
# 29981  You can never have too many zucchini recipes. ...            9.0
# 29982  If you are not fond of basil substitute with s...            NaN
# 29983  This dish is from tim malzer, a german chef wh...            5.0
# 29984  One of those email recipes i haven't tried yet...           11.0
# 29985  I came up with this sweet and spicy jam after ...            8.0
# 29986  Adapted from a recipe in 'the australian women...           12.0
# 29987  This recipe is good to have around when zucchi...           15.0
# 29988  Got this recipe from from family circle, march...           13.0
# 29989         This has been a long time family favorite!            8.0
# 29990  I got this recipe from a local paper a long ti...            NaN
# 29991  This recipe was posted in our local newspaper,...            9.0
# 29992  This is a favourite winter warmer. by british ...            NaN
# 29993  Refrigerator pickles for some of the zucchini ...            8.0
# 29994     This soup is a hearty meal!  from luisa musso.           17.0
# 29995  This is based on a french recipe but i changed...           10.0
# 29996  This is a traditional fresh plum cake, thought...           11.0
# 29997  This is a traditional late summer early fall s...            NaN
# 29998  This is a delicious soup that i originally fou...            NaN
# 29999  I've heard of the 'cookies by design' company,...           10.0
#
#        description_length
# 0                   330.0
# 1                   255.0
# 2                    39.0
# 3                   154.0
# 4                   587.0
# 5                   149.0
# 6                   290.0
# 7                    38.0
# 8                   230.0
# 9                   369.0
# 10                  294.0
# 11                   43.0
# 12                  315.0
# 13                  144.0
# 14                  240.0
# 15                  380.0
# 16                  556.0
# 17                  463.0
# 18                  385.0
# 19                  151.0
# 20                  132.0
# 21                  102.0
# 22                  544.0
# 23                  134.0
# 24                  551.0
# 25                  144.0
# 26                   54.0
# 27                  371.0
# 28                  117.0
# 29                  326.0
# ...                   ...
# 29970               113.0
# 29971                64.0
# 29972               446.0
# 29973               199.0
# 29974               285.0
# 29975               133.0
# 29976               122.0
# 29977               212.0
# 29978               253.0
# 29979               319.0
# 29980                17.0
# 29981               114.0
# 29982               100.0
# 29983               136.0
# 29984               157.0
# 29985               261.0
# 29986               888.0
# 29987               184.0
# 29988               116.0
# 29989                42.0
# 29990               275.0
# 29991               242.0
# 29992               135.0
# 29993               298.0
# 29994                46.0
# 29995               484.0
# 29996               286.0
# 29997               311.0
# 29998               648.0
# 29999               125.0
#
# [30000 rows x 9 columns]

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes["name"] = recipes["name"].str.title()
recipes
# Out:
#                                                     name      id  minutes  \
# 0                  George S At The Cove  Black Bean Soup   44123       90
# 1                     Healthy For Them  Yogurt Popsicles   67664       10
# 2                           I Can T Believe It S Spinach   38798       30
# 3                                   Italian  Gut Busters   35173       45
# 4               Love Is In The Air  Beef Fondue   Sauces   84797       25
# 5                               Mennonite  Corn Fritters   44045       15
# 6                                   Open Sesame  Noodles  107229       28
# 7                             Say What   Banana Sandwich   95926        5
# 8                     1 In Canada Chocolate Chip Cookies  453467       45
# 9                                 412 Broccoli Casserole  306168       40
# 10                                      25 000 Casserole   50662      125
# 11                         250 00 Chocolate Chip Cookies  118843       20
# 12                                     Ara S Potato  Oup   69190      135
# 13               Blepandekager   Danish   Apple Pancakes  503475       50
# 14                              Add In Anything  Muffins  149593       15
# 15                          Better Than Tofu  Cheesecake  200148       90
# 16                     Burek  Or Feta Cheese  Phyllo Pie  310570       65
# 17                   Da Best  Chicago Style Italian Beef   95534      645
# 18                             German  Barbecued Carrots  109818       55
# 19                                   Healthy  Fried Rice   66932       25
# 20                    I Can T Believe I Made Cream Puffs  226001       55
# 21                      Kelly S Creamy Cheddar Pea Salad  125195       20
# 22                         Kicked Up  Oven Fried Chicken  141939      345
# 23            Margarita  Dip For Fresh  Or Grilled Fruit  250883       70
# 24                 Middle Eastern   Twice Baked Potatoes  120297      110
# 25                        Pass Me Another   Hot Clam Dip  147477       15
# 26                         Pasta  With Shrimp   Eggplant  223349       50
# 27                               Pizza Pan  Potato Skins   60938       60
# 28                                   Quick Biscuit Bread  302399       20
# 29                       Secret Ingredient  Bbq Meatloaf  342620       75
# ...                                                  ...     ...      ...
# 29970               Zucchini Stuffed With Feta And Basil   72857       30
# 29971         Zucchini Stuffed With Goat Cheese And Mint  130447       30
# 29972        Zucchini Tart With Gruyere Cheese And Herbs  378799       35
# 29973                          Zucchini Tarte With Bacon  335783       80
# 29974                              Zucchini Tomato Salsa  321224       20
# 29975                               Zucchini Tomato Toss   41095       15
# 29976                                      Zucchini Tots  505053       20
# 29977                        Zucchini Wheat Germ Cookies  174719       30
# 29978                 Zucchini With Bacon Corn   Peppers  326105       45
# 29979               Zucchini With Bell Pepper And Tomato  363362       13
# 29980               Zucchini With Jalapeno Monterey Jack  320622       10
# 29981                                Zucchini With Pasta   96162       30
# 29982                          Zucchini With Pesto Sauce   34481       41
# 29983                          Zucchini With Serrano Ham  162411       15
# 29984  Zucchini  Corn  Black Bean  And Jack Cheese Qu...   36349       30
# 29985  Zucchini  Pineapple  Ginger Jam Kicked Up With...  325574       50
# 29986                 Zucchini  Potato And Herb Fritters  344542       30
# 29987    Zucchini Carrot Cake With Cream Cheese Frosting  112591       80
# 29988                            Zucchini Carrot Muffins  287490       40
# 29989                         Zucchini Cheddar Casserole   74023       50
# 29990                       Zucchini Pineapple Loaf Cake   71450       70
# 29991                           Zucchini Potato Pancakes  180833       45
# 29992  Zucchini  Courgette Soup  Good For Weight Watc...  415406       45
# 29993                          Zuni Caf Zucchini Pickles  316950     2895
# 29994                                     Zuppa By Luisa  464576       70
# 29995       Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996               Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997        Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                        Zydeco Soup  486161       60
# 29999             Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# 5               41706 2002-10-25      NaN
# 6              173674 2004-12-30      8.0
# 7              118163 2004-07-20      4.0
# 8             1848091 2011-04-11     12.0
# 9               50969 2008-05-30      6.0
# 10               9748 2003-01-10      NaN
# 11             145599 2005-04-24      NaN
# 12              98404 2003-08-20      5.0
# 13             128473 2013-07-08     10.0
# 14              89831 2005-12-28      NaN
# 15             261027 2006-12-11     18.0
# 16             676820 2008-06-24     38.0
# 17              94272 2004-07-13      NaN
# 18              64918 2005-01-28      NaN
# 19              93406 2003-07-16      NaN
# 20             237783 2007-05-02      NaN
# 21             113941 2005-06-09      5.0
# 22              89831 2005-10-19     13.0
# 23             398160 2007-09-04     14.0
# 24             197023 2005-05-02     14.0
# 25             135442 2005-12-05      3.0
# 26             452592 2007-04-18      7.0
# 27              35635 2003-04-24      NaN
# 28             213909 2008-05-06     11.0
# 29              50969 2008-12-09      9.0
# ...               ...        ...      ...
# 29970           95743 2003-10-08      NaN
# 29971          182809 2005-07-19     14.0
# 29972          177443 2009-06-24     16.0
# 29973          930100 2008-11-08     10.0
# 29974          464080 2008-08-25      4.0
# 29975           47579 2002-09-24      3.0
# 29976          798181 2013-07-31      NaN
# 29977          135870 2006-06-26      7.0
# 29978          896136 2008-09-19      8.0
# 29979          344321 2009-03-29     19.0
# 29980          305531 2008-08-20      3.0
# 29981          125388 2004-07-22      NaN
# 29982            4470 2002-07-17      8.0
# 29983          152500 2006-03-31      6.0
# 29984            3288 2002-08-05      NaN
# 29985           58104 2008-09-18     15.0
# 29986          197023 2008-12-21      8.0
# 29987          176348 2005-03-03      NaN
# 29988          227586 2008-02-21      NaN
# 29989           89831 2003-10-24     14.0
# 29990           89831 2003-09-15      NaN
# 29991          186118 2006-08-07      NaN
# 29992          485109 2010-03-04      5.0
# 29993           62264 2008-07-31      NaN
# 29994          226863 2011-09-20     14.0
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      An original recipe created by chef scott meska...           18.0
# 1      My children and their friends ask for my homem...            NaN
# 2                These were so go, it surprised even me.            8.0
# 3      My sister-in-law made these for us at a family...            NaN
# 4      I think a fondue is a very romantic casual din...            NaN
# 5      Ok - my heritage has been revealed. :) these a...            NaN
# 6      This is a very versatile and widely enjoyed pa...           12.0
# 7                 You just have to try it to believe it.            NaN
# 8      This is the recipe that we use at my school ca...           11.0
# 9      Since there are already 411 recipes for brocco...            NaN
# 10     This is a recipe that my mother got from some ...            NaN
# 11           These are great! the perfect name for them!           13.0
# 12     I made this recipe myself when i was 13. i was...            NaN
# 13     This recipe has been posted here for play in z...            NaN
# 14     This is a never-fail muffin recipe, it's a bla...            9.0
# 15     This is, again, from vegweb.com. this got abso...           13.0
# 16     Ok, there are different version of burek (some...            6.0
# 17     Tender, garlicky and full of oregano 'n stuff!...            NaN
# 18     This is something my grandma made at christmas...            NaN
# 19     I made this once, hoping to have something lig...            8.0
# 20     My old friend pat gave me this recipe 20 years...            6.0
# 21     I'm not a big fan of peas, but like them in th...           10.0
# 22     I make mine on one cookie rack placed on a bak...           17.0
# 23     This cool and creamy dip is a refreshing treat...            4.0
# 24     A delicious yet low-fat twice-baked potato sid...           10.0
# 25     This recipe is from an appetizer book that i i...            7.0
# 26     A nice low carb way to feel like you are eatin...            9.0
# 27     There's a pub we go to that makes their own fr...            7.0
# 28     This is a wonderful quick bread to make as an ...            5.0
# 29     I know what you might be thinking,'ho hum, ano...           10.0
# ...                                                  ...            ...
# 29970  Easy to make, savory and a nice presentation. ...            5.0
# 29971  This was past on to me by a gentleman friend w...           10.0
# 29972  This tart is wonderful picnic, potluck or part...           11.0
# 29973  This is another recipe from mark bittman's coo...            NaN
# 29974  A contest winner from taste of home.  it state...           13.0
# 29975  I tried a similar recipe but altered most of i...           10.0
# 29976  'the happy homemaker blog' shared this recipe ...            NaN
# 29977  Since i have an abundance of zucchini in my ga...           14.0
# 29978  This is a very colorful addition to any meal. ...            7.0
# 29979  The weather has been turning warmer and i have...            8.0
# 29980                                  Simple and yummy!            3.0
# 29981  You can never have too many zucchini recipes. ...            9.0
# 29982  If you are not fond of basil substitute with s...            NaN
# 29983  This dish is from tim malzer, a german chef wh...            5.0
# 29984  One of those email recipes i haven't tried yet...           11.0
# 29985  I came up with this sweet and spicy jam after ...            8.0
# 29986  Adapted from a recipe in 'the australian women...           12.0
# 29987  This recipe is good to have around when zucchi...           15.0
# 29988  Got this recipe from from family circle, march...           13.0
# 29989         This has been a long time family favorite!            8.0
# 29990  I got this recipe from a local paper a long ti...            NaN
# 29991  This recipe was posted in our local newspaper,...            9.0
# 29992  This is a favourite winter warmer. by british ...            NaN
# 29993  Refrigerator pickles for some of the zucchini ...            8.0
# 29994     This soup is a hearty meal!  from luisa musso.           17.0
# 29995  This is based on a french recipe but i changed...           10.0
# 29996  This is a traditional fresh plum cake, thought...           11.0
# 29997  This is a traditional late summer early fall s...            NaN
# 29998  This is a delicious soup that i originally fou...            NaN
# 29999  I've heard of the 'cookies by design' company,...           10.0
#
#        description_length  name_word_count
# 0                   330.0                8
# 1                   255.0                5
# 2                    39.0                7
# 3                   154.0                3
# 4                   587.0                8
# 5                   149.0                3
# 6                   290.0                3
# 7                    38.0                4
# 8                   230.0                6
# 9                   369.0                3
# 10                  294.0                3
# 11                   43.0                5
# 12                  315.0                4
# 13                  144.0                4
# 14                  240.0                4
# 15                  380.0                4
# 16                  556.0                6
# 17                  463.0                6
# 18                  385.0                3
# 19                  151.0                3
# 20                  132.0                8
# 21                  102.0                6
# 22                  544.0                5
# 23                  134.0                7
# 24                  551.0                5
# 25                  144.0                6
# 26                   54.0                4
# 27                  371.0                4
# 28                  117.0                3
# 29                  326.0                4
# ...                   ...              ...
# 29970               113.0                6
# 29971                64.0                7
# 29972               446.0                7
# 29973               199.0                4
# 29974               285.0                3
# 29975               133.0                3
# 29976               122.0                2
# 29977               212.0                4
# 29978               253.0                5
# 29979               319.0                6
# 29980                17.0                5
# 29981               114.0                3
# 29982               100.0                4
# 29983               136.0                4
# 29984               157.0                8
# 29985               261.0                9
# 29986               888.0                5
# 29987               184.0                7
# 29988               116.0                3
# 29989                42.0                3
# 29990               275.0                4
# 29991               242.0                3
# 29992               135.0                7
# 29993               298.0                4
# 29994                46.0                3
# 29995               484.0                8
# 29996               286.0                4
# 29997               311.0                5
# 29998               648.0                2
# 29999               125.0                7
#
# [30000 rows x 10 columns]

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами).

# %%
recipes["name_word_count"] = recipes["name"].str.split().str.len()
recipes
# Out:
#                                                     name      id  minutes  \
# 0                  george s at the cove  black bean soup   44123       90
# 1                     healthy for them  yogurt popsicles   67664       10
# 2                           i can t believe it s spinach   38798       30
# 3                                   italian  gut busters   35173       45
# 4               love is in the air  beef fondue   sauces   84797       25
# 5                               mennonite  corn fritters   44045       15
# 6                                   open sesame  noodles  107229       28
# 7                             say what   banana sandwich   95926        5
# 8                     1 in canada chocolate chip cookies  453467       45
# 9                                 412 broccoli casserole  306168       40
# 10                                      25 000 casserole   50662      125
# 11                         250 00 chocolate chip cookies  118843       20
# 12                                     ara s potato  oup   69190      135
# 13               blepandekager   danish   apple pancakes  503475       50
# 14                              add in anything  muffins  149593       15
# 15                          better than tofu  cheesecake  200148       90
# 16                     burek  or feta cheese  phyllo pie  310570       65
# 17                   da best  chicago style italian beef   95534      645
# 18                             german  barbecued carrots  109818       55
# 19                                   healthy  fried rice   66932       25
# 20                    i can t believe i made cream puffs  226001       55
# 21                      kelly s creamy cheddar pea salad  125195       20
# 22                         kicked up  oven fried chicken  141939      345
# 23            margarita  dip for fresh  or grilled fruit  250883       70
# 24                 middle eastern   twice baked potatoes  120297      110
# 25                        pass me another   hot clam dip  147477       15
# 26                         pasta  with shrimp   eggplant  223349       50
# 27                               pizza pan  potato skins   60938       60
# 28                                   quick biscuit bread  302399       20
# 29                       secret ingredient  bbq meatloaf  342620       75
# ...                                                  ...     ...      ...
# 29970               zucchini stuffed with feta and basil   72857       30
# 29971         zucchini stuffed with goat cheese and mint  130447       30
# 29972        zucchini tart with gruyere cheese and herbs  378799       35
# 29973                          zucchini tarte with bacon  335783       80
# 29974                              zucchini tomato salsa  321224       20
# 29975                               zucchini tomato toss   41095       15
# 29976                                      zucchini tots  505053       20
# 29977                        zucchini wheat germ cookies  174719       30
# 29978                 zucchini with bacon corn   peppers  326105       45
# 29979               zucchini with bell pepper and tomato  363362       13
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29981                                zucchini with pasta   96162       30
# 29982                          zucchini with pesto sauce   34481       41
# 29983                          zucchini with serrano ham  162411       15
# 29984  zucchini  corn  black bean  and jack cheese qu...   36349       30
# 29985  zucchini  pineapple  ginger jam kicked up with...  325574       50
# 29986                 zucchini  potato and herb fritters  344542       30
# 29987    zucchini carrot cake with cream cheese frosting  112591       80
# 29988                            zucchini carrot muffins  287490       40
# 29989                         zucchini cheddar casserole   74023       50
# 29990                       zucchini pineapple loaf cake   71450       70
# 29991                           zucchini potato pancakes  180833       45
# 29992  zucchini  courgette soup  good for weight watc...  415406       45
# 29993                          zuni caf zucchini pickles  316950     2895
# 29994                                     zuppa by luisa  464576       70
# 29995       zurie s holey rustic olive and cheddar bread  267661       80
# 29996               zwetschgenkuchen  bavarian plum cake  386977      240
# 29997        zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                        zydeco soup  486161       60
# 29999             cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# 2                1533  2002-08-29      NaN
# 3               22724  2002-07-27      NaN
# 4                4470  2004-02-23      4.0
# 5               41706  2002-10-25      NaN
# 6              173674  2004-12-30      8.0
# 7              118163  2004-07-20      4.0
# 8             1848091  2011-04-11     12.0
# 9               50969  2008-05-30      6.0
# 10               9748  2003-01-10      NaN
# 11             145599  2005-04-24      NaN
# 12              98404  2003-08-20      5.0
# 13             128473  2013-07-08     10.0
# 14              89831  2005-12-28      NaN
# 15             261027  2006-12-11     18.0
# 16             676820  2008-06-24     38.0
# 17              94272  2004-07-13      NaN
# 18              64918  2005-01-28      NaN
# 19              93406  2003-07-16      NaN
# 20             237783  2007-05-02      NaN
# 21             113941  2005-06-09      5.0
# 22              89831  2005-10-19     13.0
# 23             398160  2007-09-04     14.0
# 24             197023  2005-05-02     14.0
# 25             135442  2005-12-05      3.0
# 26             452592  2007-04-18      7.0
# 27              35635  2003-04-24      NaN
# 28             213909  2008-05-06     11.0
# 29              50969  2008-12-09      9.0
# ...               ...         ...      ...
# 29970           95743  2003-10-08      NaN
# 29971          182809  2005-07-19     14.0
# 29972          177443  2009-06-24     16.0
# 29973          930100  2008-11-08     10.0
# 29974          464080  2008-08-25      4.0
# 29975           47579  2002-09-24      3.0
# 29976          798181  2013-07-31      NaN
# 29977          135870  2006-06-26      7.0
# 29978          896136  2008-09-19      8.0
# 29979          344321  2009-03-29     19.0
# 29980          305531  2008-08-20      3.0
# 29981          125388  2004-07-22      NaN
# 29982            4470  2002-07-17      8.0
# 29983          152500  2006-03-31      6.0
# 29984            3288  2002-08-05      NaN
# 29985           58104  2008-09-18     15.0
# 29986          197023  2008-12-21      8.0
# 29987          176348  2005-03-03      NaN
# 29988          227586  2008-02-21      NaN
# 29989           89831  2003-10-24     14.0
# 29990           89831  2003-09-15      NaN
# 29991          186118  2006-08-07      NaN
# 29992          485109  2010-03-04      5.0
# 29993           62264  2008-07-31      NaN
# 29994          226863  2011-09-20     14.0
# 29995          200862  2007-11-25     16.0
# 29996          177443  2009-08-24      NaN
# 29997          161745  2004-11-03      NaN
# 29998          227978  2012-08-29      NaN
# 29999          506822  2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# 5      ok - my heritage has been revealed. :) these a...            NaN
# 6      this is a very versatile and widely enjoyed pa...           12.0
# 7                 you just have to try it to believe it.            NaN
# 8      this is the recipe that we use at my school ca...           11.0
# 9      since there are already 411 recipes for brocco...            NaN
# 10     this is a recipe that my mother got from some ...            NaN
# 11           these are great! the perfect name for them!           13.0
# 12     i made this recipe myself when i was 13. i was...            NaN
# 13     this recipe has been posted here for play in z...            NaN
# 14     this is a never-fail muffin recipe, it's a bla...            9.0
# 15     this is, again, from vegweb.com. this got abso...           13.0
# 16     ok, there are different version of burek (some...            6.0
# 17     tender, garlicky and full of oregano 'n stuff!...            NaN
# 18     this is something my grandma made at christmas...            NaN
# 19     i made this once, hoping to have something lig...            8.0
# 20     my old friend pat gave me this recipe 20 years...            6.0
# 21     i'm not a big fan of peas, but like them in th...           10.0
# 22     i make mine on one cookie rack placed on a bak...           17.0
# 23     this cool and creamy dip is a refreshing treat...            4.0
# 24     a delicious yet low-fat twice-baked potato sid...           10.0
# 25     this recipe is from an appetizer book that i i...            7.0
# 26     a nice low carb way to feel like you are eatin...            9.0
# 27     there's a pub we go to that makes their own fr...            7.0
# 28     this is a wonderful quick bread to make as an ...            5.0
# 29     i know what you might be thinking,'ho hum, ano...           10.0
# ...                                                  ...            ...
# 29970  easy to make, savory and a nice presentation. ...            5.0
# 29971  this was past on to me by a gentleman friend w...           10.0
# 29972  this tart is wonderful picnic, potluck or part...           11.0
# 29973  this is another recipe from mark bittman's coo...            NaN
# 29974  a contest winner from taste of home.  it state...           13.0
# 29975  i tried a similar recipe but altered most of i...           10.0
# 29976  'the happy homemaker blog' shared this recipe ...            NaN
# 29977  since i have an abundance of zucchini in my ga...           14.0
# 29978  this is a very colorful addition to any meal. ...            7.0
# 29979  the weather has been turning warmer and i have...            8.0
# 29980                                  simple and yummy!            3.0
# 29981  you can never have too many zucchini recipes. ...            9.0
# 29982  if you are not fond of basil substitute with s...            NaN
# 29983  this dish is from tim malzer, a german chef wh...            5.0
# 29984  one of those email recipes i haven't tried yet...           11.0
# 29985  i came up with this sweet and spicy jam after ...            8.0
# 29986  adapted from a recipe in 'the australian women...           12.0
# 29987  this recipe is good to have around when zucchi...           15.0
# 29988  got this recipe from from family circle, march...           13.0
# 29989         this has been a long time family favorite!            8.0
# 29990  i got this recipe from a local paper a long ti...            NaN
# 29991  this recipe was posted in our local newspaper,...            9.0
# 29992  this is a favourite winter warmer. by british ...            NaN
# 29993  refrigerator pickles for some of the zucchini ...            8.0
# 29994     this soup is a hearty meal!  from luisa musso.           17.0
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        name_word_count
# 0                    8
# 1                    5
# 2                    7
# 3                    3
# 4                    8
# 5                    3
# 6                    3
# 7                    4
# 8                    6
# 9                    3
# 10                   3
# 11                   5
# 12                   4
# 13                   4
# 14                   4
# 15                   4
# 16                   6
# 17                   6
# 18                   3
# 19                   3
# 20                   8
# 21                   6
# 22                   5
# 23                   7
# 24                   5
# 25                   6
# 26                   4
# 27                   4
# 28                   3
# 29                   4
# ...                ...
# 29970                6
# 29971                7
# 29972                7
# 29973                4
# 29974                3
# 29975                3
# 29976                2
# 29977                4
# 29978                5
# 29979                6
# 29980                5
# 29981                3
# 29982                4
# 29983                4
# 29984                8
# 29985                9
# 29986                5
# 29987                7
# 29988                3
# 29989                3
# 29990                4
# 29991                3
# 29992                7
# 29993                4
# 29994                3
# 29995                8
# 29996                4
# 29997                5
# 29998                2
# 29999                7
#
# [30000 rows x 9 columns]

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
group_contributor = recipes.groupby("contributor_id", sort=False)
print(group_contributor.size())
print(group_contributor.size().idxmax())
# Out:
# contributor_id
# 35193       18
# 91970        1
# 1533       186
# 22724        4
# 4470       141
# 41706       15
# 173674       2
# 118163      18
# 1848091      2
# 50969       33
# 9748         4
# 145599      20
# 98404        1
# 128473      61
# 89831      421
# 261027       2
# 676820       4
# 94272       37
# 64918        6
# 93406        1
# 237783       9
# 113941      39
# 398160      10
# 197023      46
# 135442       4
# 452592       3
# 35635       24
# 213909       9
# 718054       7
# 290107      16
#           ...
# 1397217      1
# 340552       1
# 173438       1
# 405004       1
# 512679       1
# 2143923      1
# 369264       1
# 583331       1
# 279179       1
# 76596        1
# 130849       1
# 967098       1
# 31953        1
# 76559        1
# 250326       1
# 91824        1
# 47541        1
# 423555       1
# 35251        1
# 1302877      1
# 1041402      1
# 135887       1
# 94472        1
# 212714       1
# 1885554      1
# 522304       1
# 896136       1
# 344321       1
# 152500       1
# 186118       1
# Length: 8404, dtype: int64
# 89831

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы?

# %%
group_id = reviews.groupby("recipe_id", sort=False)
print(group_id["rating"].mean())
print(sum(group_id.apply(lambda x: x["review"].isnull().sum())))
# Out:
# recipe_id
# 57993     4.818182
# 142201    4.583333
# 252013    4.000000
# 404716    3.727273
# 129396    5.000000
# 31322     4.500000
# 199579    4.500000
# 16067     4.862069
# 33715     5.000000
# 11252     4.384615
# 285773    3.800000
# 154996    4.642857
# 7974      4.500000
# 150499    4.411765
# 114415    5.000000
# 109536    4.512821
# 21171     4.688525
# 49200     4.577540
# 51209     4.521739
# 320714    4.666667
# 38249     4.060606
# 213395    5.000000
# 171615    5.000000
# 122289    4.250000
# 148347    4.222222
# 328668    4.545455
# 42603     4.516854
# 300681    5.000000
# 299881    4.833333
# 61610     4.560440
#             ...
# 445486    5.000000
# 76522     5.000000
# 70819     5.000000
# 122746    5.000000
# 291080    4.000000
# 497993    5.000000
# 534283    5.000000
# 442306    5.000000
# 407031    5.000000
# 407964    3.000000
# 359145    5.000000
# 415430    5.000000
# 10569     4.000000
# 392509    5.000000
# 97995     4.000000
# 281407    4.000000
# 347554    0.000000
# 221923    3.000000
# 192564    5.000000
# 512728    4.000000
# 263548    4.000000
# 444315    5.000000
# 162824    5.000000
# 274758    0.000000
# 422945    5.000000
# 94096     5.000000
# 368208    2.000000
# 154964    5.000000
# 187418    5.000000
# 296868    4.000000
# Name: rating, Length: 28100, dtype: float64
# 17

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
print(recipes.groupby(pd.Grouper(key="submitted", freq="Y")).size())
# Out:
# submitted
# 1999-12-31     275
# 2000-12-31     104
# 2001-12-31     589
# 2002-12-31    2644
# 2003-12-31    2334
# 2004-12-31    2153
# 2005-12-31    3130
# 2006-12-31    3473
# 2007-12-31    4429
# 2008-12-31    4029
# 2009-12-31    2963
# 2010-12-31    1538
# 2011-12-31     922
# 2012-12-31     659
# 2013-12-31     490
# 2014-12-31     139
# 2015-12-31      42
# 2016-12-31      24
# 2017-12-31      39
# 2018-12-31      24
# Freq: A-DEC, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты без отзывов должны отсутствовать в данной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и выведя на экран строку из полученного `DataFrame`, содержащую информацию об этом отзыве.

# %%
merge_df = recipes.merge(reviews, left_on="id", right_on="recipe_id", how="inner")
merge_df = merge_df[["id", "name", "user_id", "rating"]]
merge_df
# Out:
#             id                                               name     user_id  \
# 0        44123              george s at the cove  black bean soup      743566
# 1        44123              george s at the cove  black bean soup       76503
# 2        44123              george s at the cove  black bean soup       34206
# 3        67664                 healthy for them  yogurt popsicles      494084
# 4        67664                 healthy for them  yogurt popsicles      303445
# 5        67664                 healthy for them  yogurt popsicles       32772
# 6        67664                 healthy for them  yogurt popsicles      161653
# 7        67664                 healthy for them  yogurt popsicles      124268
# 8        67664                 healthy for them  yogurt popsicles     1585803
# 9        67664                 healthy for them  yogurt popsicles      818740
# 10       67664                 healthy for them  yogurt popsicles      176615
# 11       38798                       i can t believe it s spinach      125798
# 12       38798                       i can t believe it s spinach      110034
# 13       38798                       i can t believe it s spinach      487548
# 14       35173                               italian  gut busters       44661
# 15       84797           love is in the air  beef fondue   sauces      123871
# 16       84797           love is in the air  beef fondue   sauces      509740
# 17       84797           love is in the air  beef fondue   sauces      110905
# 18       84797           love is in the air  beef fondue   sauces      560694
# 19       84797           love is in the air  beef fondue   sauces       11176
# 20       84797           love is in the air  beef fondue   sauces      257993
# 21       84797           love is in the air  beef fondue   sauces      198228
# 22       84797           love is in the air  beef fondue   sauces      128047
# 23       44045                           mennonite  corn fritters       99872
# 24       44045                           mennonite  corn fritters      124249
# 25       44045                           mennonite  corn fritters       52073
# 26       44045                           mennonite  corn fritters      189287
# 27       44045                           mennonite  corn fritters      164890
# 28      107229                               open sesame  noodles      133842
# 29       95926                         say what   banana sandwich  2000533197
# ...        ...                                                ...         ...
# 126666  180833                           zucchini potato pancakes      119859
# 126667  180833                           zucchini potato pancakes      424680
# 126668  415406  zucchini  courgette soup  good for weight watc...      450004
# 126669  415406  zucchini  courgette soup  good for weight watc...      386585
# 126670  415406  zucchini  courgette soup  good for weight watc...      141569
# 126671  316950                          zuni caf zucchini pickles      579544
# 126672  316950                          zuni caf zucchini pickles      207472
# 126673  316950                          zuni caf zucchini pickles     1072593
# 126674  464576                                     zuppa by luisa      386585
# 126675  464576                                     zuppa by luisa      315565
# 126676  464576                                     zuppa by luisa      169430
# 126677  267661       zurie s holey rustic olive and cheddar bread       93006
# 126678  267661       zurie s holey rustic olive and cheddar bread      232886
# 126679  267661       zurie s holey rustic olive and cheddar bread       55729
# 126680  267661       zurie s holey rustic olive and cheddar bread      538190
# 126681  386977               zwetschgenkuchen  bavarian plum cake     2345744
# 126682  386977               zwetschgenkuchen  bavarian plum cake  2000435313
# 126683  103312        zwiebelkuchen   southwest german onion cake     1925885
# 126684  103312        zwiebelkuchen   southwest german onion cake     2058344
# 126685  103312        zwiebelkuchen   southwest german onion cake    11344701
# 126686  103312        zwiebelkuchen   southwest german onion cake     1711977
# 126687  103312        zwiebelkuchen   southwest german onion cake      171790
# 126688  103312        zwiebelkuchen   southwest german onion cake  2002179144
# 126689  486161                                        zydeco soup      226863
# 126690  486161                                        zydeco soup      498271
# 126691  486161                                        zydeco soup      305531
# 126692  486161                                        zydeco soup     1271506
# 126693  486161                                        zydeco soup      724631
# 126694  486161                                        zydeco soup      133174
# 126695  298512             cookies by design   cookies on a stick      804234
#
#         rating
# 0            5
# 1            5
# 2            5
# 3            5
# 4            5
# 5            5
# 6            5
# 7            5
# 8            5
# 9            5
# 10           5
# 11           3
# 12           4
# 13           4
# 14           4
# 15           5
# 16           3
# 17           5
# 18           5
# 19           0
# 20           5
# 21           5
# 22           4
# 23           5
# 24           5
# 25           5
# 26           4
# 27           5
# 28           5
# 29           5
# ...        ...
# 126666       0
# 126667       5
# 126668       5
# 126669       4
# 126670       5
# 126671       5
# 126672       5
# 126673       5
# 126674       5
# 126675       5
# 126676       5
# 126677       5
# 126678       5
# 126679       0
# 126680       5
# 126681       5
# 126682       5
# 126683       4
# 126684       5
# 126685       4
# 126686       0
# 126687       5
# 126688       4
# 126689       5
# 126690       5
# 126691       5
# 126692       5
# 126693       5
# 126694       5
# 126695       1
#
# [126696 rows x 4 columns]

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`. У рецептов, для которых отсутствуют отзывы, в соответствущем столбце должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и выведя на экран строку из полученного `DataFrame`, содержащую информацию об этом отзыве.

# %%
merge_df_2 = recipes.merge(reviews, left_on="id", right_on="recipe_id", how="left")
# nan_reviews = merge_df_2[merge_df_2["review"].isnull()]["id"]
merge_df_2 = merge_df_2[["recipe_id", "name"]]
merge_df_2 = merge_df_2.groupby(["recipe_id", "name"]).size().to_frame(name = 'review_count')
merge_df_2
# Out:
#                                                               review_count
# recipe_id name
# 48.0      Boston Cream Pie                                               2
# 55.0      Betty Crocker S Southwestern Guacamole Dip                     4
# 66.0      Black Coffee Barbecue Sauce                                   18
# 91.0      Brown Rice And Vegetable Pilaf                                 4
# 94.0      Blueberry Buttertarts                                          4
# 128.0     Caramel Apple Milkshakes                                       2
# 148.0     Bugwiches                                                      1
# 153.0     Amish Friendship Bread And Starter                            39
# 176.0     Cola Cake                                                      1
# 181.0     Chicken With Portabella Mushrooms                              3
# 186.0     Coca Cola Cake                                                 9
# 203.0     Chinese Plum Sauce                                            14
# 224.0     Chocolate Tapioca Pudding                                      5
# 240.0     Chicken Fried Brown Rice                                       7
# 246.0     Lee S Hot Crab Dip                                            54
# 282.0     Thai Coconut Chicken Soup                                      2
# 284.0     Thai Fried Bananas                                             1
# 288.0     Thai Coconut Custard                                           3
# 289.0     Feijoada  Brazilian Bean Soup  Ii                              1
# 314.0     Thai Citrus Chicken Salad                                     11
# 318.0     French Pecan Pie Ii                                            4
# 321.0     Drunken Chicken Ii                                             1
# 337.0     Oktoberfest Spinach Strudel                                    1
# 344.0     Secret Salsa                                                   1
# 352.0     Banana Orange Ice Cream                                        4
# 360.0     Baked Zucchini Frittatas                                       1
# 373.0     Tiramisu   Balducci S In New York City                         1
# 378.0     Sweet Potato Pecan Pie                                        16
# 379.0     Corn Salsa                                                     6
# 381.0     Southern Sweet Potato Pie                                      5
# ...                                                                    ...
# 534062.0  Copycat Hamburger Helper Rice Oriental                         1
# 534064.0  Purple Gnocchi With Shiitake Mushrooms                         1
# 534196.0  Brussels Sprouts Bites                                         1
# 534283.0  Creamy Corn Pudding                                            1
# 534393.0  Braised Cauliflower With Bacon                                 1
# 534549.0  Mimi S Date Squares  Gluten Free                               1
# 534786.0  White Bean And Chicken Chili                                   1
# 534855.0  Instant Pot Goulash                                            1
# 535104.0  Fruit Loop Treats                                              1
# 535120.0  Easy Bagel Dogs Weight Watchers Friendly                       1
# 535269.0  Sweet Tea Baby Back Ribs                                       1
# 535312.0  Samoa Sheet Cake                                               1
# 535389.0  Vietnamese Chicken                                             1
# 535555.0  The Best Ground Beef Tacos On The Planet                       2
# 535584.0  Filet Mignon                                                   1
# 535650.0  Mexican Style Pickled Vegetables                               2
# 535691.0  Royal Crown Strawberry Pie                                     1
# 535713.0  Hawaiian Cheesecake Fruit Salad                                1
# 535783.0  Cheesesteak Stuffed Onion Rings                                2
# 536051.0  Hawaiian Shrimp Truck Special  Garlic Lemon But...             4
# 536066.0  Widow S Soup                                                   1
# 536098.0  Gotham Rib Steak                                               1
# 536212.0  Slow Cooker Cheesy Bacon Ranch Potatoes                        1
# 536360.0  Hamburger Potpie With Homemade Crust                           1
# 536473.0  Pineapple Cannoli Cones                                        1
# 536547.0  Cauliflower Ceviche                                            1
# 536610.0  Miracle Home Made Puff Pastry                                  1
# 536728.0  Gluten Free  Vegemite                                          1
# 536729.0  Creole Watermelon Feta Salad                                   4
# 536747.0  Lemon Pom Pom Cake                                             4
#
# [28100 rows x 1 columns]

# %%
merge_df_2[merge_df_2["recipe_id"] == 9054]
# Out:
#      recipe_id                             name  review_count
# 404       9054  leftover mashed potato pancakes            90

# %% [markdown]
# 5.3. Выясните, отзывы, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
merge_df_3 = recipes.merge(reviews, left_on="id", right_on="recipe_id", how="inner")
merge_df_3 = merge_df_3.groupby(pd.Grouper(key="submitted", freq="Y"))["rating"].mean()
merge_df_3.loc[merge_df_3 == merge_df_3.min()].index[0].year
# Out:
# 2017

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes = recipes.sort_values(by="name_word_count", ascending=False)
recipes.to_csv(path + "name_word_count.csv")

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter(path + "merging.xlsx") as writer:
    merge_df.to_excel(writer, sheet_name="Рецепты с оценками", index=False)
    merge_df_2.to_excel(writer, sheet_name="Количество отзывов по рецептам")
